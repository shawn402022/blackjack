# %%
#create gloabal class

class Blackjack():
    def __init__(self,play):
        self.play = play

# %%
class Cards(Blackjack):
    
    def __init__(self,value,suit,play):
        self.value = value
        self.suit = suit
        super().__init__(play,)



        
# Diamond cards
        
d_1 = Cards(1,'diamonds', True)
d_2 = Cards(2,'diamonds', True)
d_3 = Cards(3,'diamonds', True)
d_4 = Cards(4,'diamonds', True)
d_5 = Cards(5,'diamonds', True)
d_6 = Cards(6,'diamonds', True)
d_7 = Cards(7,'diamonds', True)
d_8 = Cards(8,'diamonds', True)
d_9 = Cards(9,'diamonds', True)
d_10 = Cards(10,'diamonds', True)
d_11 = Cards(11,'diamonds', True)
d_12 = Cards(12,'diamonds', True)
d_13 = Cards(13,'diamonds', True)

# heart cards

h_1 = Cards(1,'hearts', True)
h_2 = Cards(2,'hearts', True)
h_3 = Cards(3,'hearts', True)
h_4 = Cards(4,'hearts', True)
h_5 = Cards(5,'hearts', True)
h_6 = Cards(6,'hearts', True)
h_7 = Cards(7,'hearts', True)
h_8 = Cards(8,'hearts', True)
h_9 = Cards(9,'hearts', True)
h_10 = Cards(10,'hearts', True)
h_11 = Cards(11,'hearts', True)
h_12 = Cards(12,'hearts', True)
h_13 = Cards(13,'hearts', True)

# spade cards

s_1 = Cards(1,'spades', True)
s_2 = Cards(2,'spades', True)
s_3 = Cards(3,'spades', True)
s_4 = Cards(4,'spades', True)
s_5 = Cards(5,'spades', True)
s_6 = Cards(6,'spades', True)
s_7 = Cards(7,'spades', True)
s_8 = Cards(8,'spades', True)
s_9 = Cards(9,'spades', True)
s_10 = Cards(10,'spades', True)
s_11 = Cards(11,'spades', True)
s_12 = Cards(12,'spades', True)
s_13 = Cards(13,'spades', True)

# clover

c_1 = Cards(1,'clovers', True)
c_2 = Cards(2,'clovers', True)
c_3 = Cards(3,'clovers', True)
c_4 = Cards(4,'clovers', True)
c_5 = Cards(5,'clovers', True)
c_6 = Cards(6,'clovers', True)
c_7 = Cards(7,'clovers', True)
c_8 = Cards(8,'clovers', True)
c_9 = Cards(9,'clovers', True)
c_10 = Cards(10,'clovers', True)
c_11 = Cards(11,'clovers', True)
c_12 = Cards(12,'clovers', True)
c_13 = Cards(13,'clovers', True)


#list with alll the cards

deck = [
    d_1, d_2, d_3, d_4, d_5, d_6, d_7, d_8, d_9, d_10, d_11, d_12, d_13,
    h_1, h_2, h_3, h_4, h_5, h_6, h_7, h_8, h_9, h_10, h_11, h_12, h_13,
    s_1, s_2, s_3, s_4, s_5, s_6, s_7, s_8, s_9, s_10, d_11, s_12, s_13,
    c_1, c_2, c_3, c_4, c_5, c_6, c_7, c_8, c_9, c_10, c_11, c_12, c_13
       ]

# %%
class Participant(Blackjack):
    def __init__(self,play):
        super().__init__(play)
    
    
dealer = Participant(True)
dealer_hand = []


player = Participant(True)
player_hand = []

# %%
# functinos needed for the game
def blackjack():

    def win():
        pass

    def shuffle():
        random.shuffle(deck)

    def show():
        pass

    def hit():
        pass

    def bust():
        pass

    def call():
        pass
        
    def count():
        pass
        
    def total():
        pass

# %%
# class Blackjack():
#     def __init__(self,win,shuffle,show,hit,bust,call_it, count,total):
#         self.win = win
#         self.shuffle = shuffle
#         self.show = show
#         self.hit = hit
#         self.bust = bust
#         self.compare = call_it
#         self.count = count
#         self.total = total
